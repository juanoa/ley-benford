# %%
import requests
import json

import matplotlib.pyplot as plt

# %%
BENFORD_ARRAY = [0.301, 0.176, 0.125, 0.097, 0.079, 0.067, 0.058, 0.051, 0.046]

x = range (1, 10)
plt.bar(x, BENFORD_ARRAY, label='Ley de Benford')
plt.legend()
plt.show()

def imprimir_resultado(primeros_digitos):
    numero_de_datos = len(primeros_digitos)
    print('Tamaño de la muestra: '+ str(numero_de_datos)+'\n')
    porcentajes = []

    for numero in range (1, 10):
        cantidad = primeros_digitos.count(numero)
        porcentaje = round(float(cantidad)/float(numero_de_datos), 3)
        porcentajes.append(porcentaje)
        benford = BENFORD_ARRAY[numero-1]
        diferencia = round(abs(benford-porcentaje), 3)
        print('Numero ' + str(numero) + ':\t' + str(porcentaje) + '\t | \t' + str(benford) + '\t diferencia de ' + str(diferencia))

    x = range (1, 10)
    y = porcentajes
    
    plt.bar(x, y, label='Resultado')
    plt.plot(x, BENFORD_ARRAY, 'ro' , label='Ley de Benford')

    plt.legend()
    plt.show()

# %%
# PRIMER CASO
# POBLACION DE LOS MUNICIPIOS ESPAÑOLES

# De un fichero JSON con la población de los municipios en España en el año 2016, obtenemos el primer dígito de cada uno y comprbamos si cumple la Ley de Benford.

# %%
primeros_digitos = []

with open('municipios.json') as f:
  datos = json.load(f)
  for municipio in datos['municipios']:
      primeros_digitos.append(int(str(municipio['poblacion'])[0]))

imprimir_resultado(primeros_digitos)
# Out:
# Tamaño de la muestra: 8110
#
# Numero 1:	0.321	 | 	0.301	 diferencia de 0.02
# Numero 2:	0.182	 | 	0.176	 diferencia de 0.006
# Numero 3:	0.124	 | 	0.125	 diferencia de 0.001
# Numero 4:	0.09	 | 	0.097	 diferencia de 0.007
# Numero 5:	0.081	 | 	0.079	 diferencia de 0.002
# Numero 6:	0.064	 | 	0.067	 diferencia de 0.003
# Numero 7:	0.056	 | 	0.058	 diferencia de 0.002
# Numero 8:	0.044	 | 	0.051	 diferencia de 0.007
# Numero 9:	0.037	 | 	0.046	 diferencia de 0.009

# %%
# SEGUNDO CASO
# VALOR DEL BITCOIN

# De un fichero JSON (bitcoin.json) con las cotizaciones del Bitcoin (BTC) desde 2010, obtenemos el primer dígito del precio de cierre de cada una y comprobamos si cumple la Ley de Benford.

# %%
primeros_digitos = []

with open('bitcoin.json') as f:
  datos = json.load(f)
  for cotizacion in datos:
      primeros_digitos.append(int(str(cotizacion['Price'])[0]))

imprimir_resultado(primeros_digitos)
# Out:
# Tamaño de la muestra: 3860
#
# Numero 1:	0.226	 | 	0.301	 diferencia de 0.075
# Numero 2:	0.12	 | 	0.176	 diferencia de 0.056
# Numero 3:	0.104	 | 	0.125	 diferencia de 0.021
# Numero 4:	0.106	 | 	0.097	 diferencia de 0.009
# Numero 5:	0.078	 | 	0.079	 diferencia de 0.001
# Numero 6:	0.106	 | 	0.067	 diferencia de 0.039
# Numero 7:	0.063	 | 	0.058	 diferencia de 0.005
# Numero 8:	0.059	 | 	0.051	 diferencia de 0.008
# Numero 9:	0.071	 | 	0.046	 diferencia de 0.025

# %%
# TERCER CASO
# CASOS DE COVID EN LOS MUNICIPIOS DE EEUU

# De un fichero JSON (covid.json) con los casos de COVID de todos los municipios de EEUU, obtenemos el primer dígito del número de casos y comprobamos si cumple la Ley de Benford.

# %%
primeros_digitos = []

with open('covid.json') as f:
  datos = json.load(f)
  for casos in datos:
      primeros_digitos.append(int(str(casos['cases'])[0]))

imprimir_resultado(primeros_digitos)
# Out:
# Tamaño de la muestra: 3245
#
# Numero 1:	0.31	 | 	0.301	 diferencia de 0.009
# Numero 2:	0.178	 | 	0.176	 diferencia de 0.002
# Numero 3:	0.132	 | 	0.125	 diferencia de 0.007
# Numero 4:	0.096	 | 	0.097	 diferencia de 0.001
# Numero 5:	0.071	 | 	0.079	 diferencia de 0.008
# Numero 6:	0.063	 | 	0.067	 diferencia de 0.004
# Numero 7:	0.059	 | 	0.058	 diferencia de 0.001
# Numero 8:	0.05	 | 	0.051	 diferencia de 0.001
# Numero 9:	0.04	 | 	0.046	 diferencia de 0.006

# %%
# CUARTO CASO
# PRECIOS DE PRODUCTOS DE AMAZON EN USA

# De un fichero JSON (amazon.json) con los precios más bajos de productos de Amazon en EEUU, obtenemos el primer dígito del precio y comprobamos si cumple la Ley de Benford.

# %%
primeros_digitos = []

with open('amazon.json') as f:
  datos = json.load(f)
  for casos in datos:
      primeros_digitos.append(int(str(casos['Lowest Price'])[0]))

imprimir_resultado(primeros_digitos)
# Out:
# Tamaño de la muestra: 30015
#
# Numero 1:	0.271	 | 	0.301	 diferencia de 0.03
# Numero 2:	0.135	 | 	0.176	 diferencia de 0.041
# Numero 3:	0.105	 | 	0.125	 diferencia de 0.02
# Numero 4:	0.082	 | 	0.097	 diferencia de 0.015
# Numero 5:	0.119	 | 	0.079	 diferencia de 0.04
# Numero 6:	0.101	 | 	0.067	 diferencia de 0.034
# Numero 7:	0.072	 | 	0.058	 diferencia de 0.014
# Numero 8:	0.057	 | 	0.051	 diferencia de 0.006
# Numero 9:	0.053	 | 	0.046	 diferencia de 0.007

# %%
# QUINTO CASO
# CAPACIDAD DE PRODUCCIÓN DE ELECTRICIDAD DE TODAS LAS PLANTAS DEL MUNDO

# De un fichero JSON (electricidad.json) con los datos de todas las plantas de generación de electricidad del mundo, obtenemos el primer dígito de su capacidad en MW y comprobamos si cumple la Ley de Benford.

# %%
primeros_digitos = []

with open('electricidad.json') as f:
  datos = json.load(f)
  for casos in datos:
      primeros_digitos.append(int(str(casos['capacity_mw'])[0]))

imprimir_resultado(primeros_digitos)
# Out:
# Tamaño de la muestra: 29910
#
# Numero 1:	0.346	 | 	0.301	 diferencia de 0.045
# Numero 2:	0.181	 | 	0.176	 diferencia de 0.005
# Numero 3:	0.109	 | 	0.125	 diferencia de 0.016
# Numero 4:	0.107	 | 	0.097	 diferencia de 0.01
# Numero 5:	0.079	 | 	0.079	 diferencia de 0.0
# Numero 6:	0.062	 | 	0.067	 diferencia de 0.005
# Numero 7:	0.041	 | 	0.058	 diferencia de 0.017
# Numero 8:	0.04	 | 	0.051	 diferencia de 0.011
# Numero 9:	0.034	 | 	0.046	 diferencia de 0.012

# %%
# SEXTO CASO
# LÍNEAS DE CÓDIGO

# De un fichero JSON (codigo.json) con los datos de errores tipográficos encontrados en repositorios de GitHub, obtenemos el primer dígito de la linea en la que se ha encontrado el error y comprobamos si cumple la Ley de Benford.

# %%
primeros_digitos = []

with open('codigo.json') as f:
  datos = json.load(f)
  for casos in datos:
      primeros_digitos.append(int(str(casos['line'])[0]))

imprimir_resultado(primeros_digitos)
# Out:
# Tamaño de la muestra: 7374
#
# Numero 1:	0.286	 | 	0.301	 diferencia de 0.015
# Numero 2:	0.171	 | 	0.176	 diferencia de 0.005
# Numero 3:	0.122	 | 	0.125	 diferencia de 0.003
# Numero 4:	0.095	 | 	0.097	 diferencia de 0.002
# Numero 5:	0.08	 | 	0.079	 diferencia de 0.001
# Numero 6:	0.067	 | 	0.067	 diferencia de 0.0
# Numero 7:	0.058	 | 	0.058	 diferencia de 0.0
# Numero 8:	0.057	 | 	0.051	 diferencia de 0.006
# Numero 9:	0.048	 | 	0.046	 diferencia de 0.002
